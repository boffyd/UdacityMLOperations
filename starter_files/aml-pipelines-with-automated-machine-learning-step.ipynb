# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.27.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-145533
# aml-quickstarts-145533
# southcentralus
# 5a4ab2ba-6c51-4805-8155-58759ad589d8

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-145533)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "ComputeCluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankDataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [b1b76671][b298309d-a045-4524-aa1b-6aefb88070fa], (This step will run and generate new outputs)
# Submitted PipelineRun 6b86c590-1c37-4db9-8451-364d245ea20f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/6b86c590-1c37-4db9-8451-364d245ea20f?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-145533/workspaces/quick-starts-ws-145533&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 6b86c590-1c37-4db9-8451-364d245ea20f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/6b86c590-1c37-4db9-8451-364d245ea20f?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-145533/workspaces/quick-starts-ws-145533&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: 8438967f-0359-4a20-8688-88c4be141fbc
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8438967f-0359-4a20-8688-88c4be141fbc?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-145533/workspaces/quick-starts-ws-145533&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '8438967f-0359-4a20-8688-88c4be141fbc', 'target': 'ComputeCluster', 'status': 'Completed', 'startTimeUtc': '2021-05-24T10:45:12.829591Z', 'endTimeUtc': '2021-05-24T11:18:41.643728Z', 'properties': {'ContentSnapshotId': '54dc066b-3529-4a63-bcbb-c5e079d28dba', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'b298309d-a045-4524-aa1b-6aefb88070fa', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'b1b76671', 'azureml.pipelinerunid': '6b86c590-1c37-4db9-8451-364d245ea20f', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'ComputeCluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "5a4ab2ba-6c51-4805-8155-58759ad589d8", "resource_group": "aml-quickstarts-145533", "workspace_name": "quick-starts-ws-145533", "region": "southcentralus", "compute_target": "ComputeCluster", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "test_size": 0.0, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["RandomForest", "MultinomialNaiveBayes", "BernoulliNaiveBayes", "KNN", "SVM", "SGD", "LinearSVM", "XGBoostClassifier", "DecisionTree", "AveragedPerceptronClassifier", "TensorFlowLinearClassifier", "GradientBoosting", "ExtremeRandomTrees", "LogisticRegression", "LightGBM", "TensorFlowDNN"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "save_mlflow": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"01a69f8e-003c-4e68-b811-e15f6229c67b\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '54dc066b-3529-4a63-bcbb-c5e079d28dba', 'SetupRunId': '8438967f-0359-4a20-8688-88c4be141fbc_setup', 'SetupRunContainerId': 'dcid.8438967f-0359-4a20-8688-88c4be141fbc_setup', 'ClientSdkVersion': '1.27.0', 'Featuriz ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '6b86c590-1c37-4db9-8451-364d245ea20f', 'status': 'Completed', 'startTimeUtc': '2021-05-24T10:44:56.291878Z', 'endTimeUtc': '2021-05-24T11:20:02.367008Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg145533.blob.core.windows.net/azureml/ExperimentRun/dcid.6b86c590-1c37-4db9-8451-364d245ea20f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=3aRZAjO%2BL%2FhhzDJIsNtiruQaN%2BUc5mv7WZBnKHDFHf4%3D&st=2021-05-24T10%3A35%3A04Z&se=2021-05-24T18%3A45%3A04Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg145533.blob.core.windows.net/azureml/ExperimentRun/dcid.6b86c590-1c37-4db9-8451-364d245ea20f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=D4eXZPZ1cZQK8m5YUEzZNJf%2BtZ%2FDX6fz3VNk6lXl26Q%3D&st=2021-05-24T10%3A35%3A04Z&se=2021-05-24T18%3A45%3A04Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg145533.blob.core.windows.net/azureml/ExperimentRun/dcid.6b86c590-1c37-4db9-8451-364d245ea20f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=fiO4QUPR8V89A%2BPXF%2FdZlodF%2Bo2UT8W%2B9HLDXqOKflI%3D&st=2021-05-24T10%3A35%3A04Z&se=2021-05-24T18%3A45%3A04Z&sp=r'}, 'submittedBy': 'ODL_User 145533'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/8438967f-0359-4a20-8688-88c4be141fbc/metrics_data
# Downloaded azureml/8438967f-0359-4a20-8688-88c4be141fbc/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  8438967f-0359-4a20-8688-88c4be141fbc_3  \
# balanced_accuracy                                  [0.8338093941431555]
# f1_score_macro                                     [0.6918486568966635]
# norm_macro_recall                                  [0.6676187882863109]
# average_precision_score_micro                       [0.866181791940016]
# accuracy                                           [0.8078907435508346]
# f1_score_weighted                                  [0.8385942630167008]
# recall_score_micro                                 [0.8078907435508346]
# precision_score_weighted                            [0.909455367903091]
# weighted_accuracy                                  [0.8014558436963971]
# f1_score_micro                                     [0.8078907435508346]
# matthews_correlation                               [0.4718510120431803]
# recall_score_weighted                              [0.8078907435508346]
# log_loss                                           [0.5014033696253982]
# AUC_macro                                          [0.8990871487662244]
# recall_score_macro                                 [0.8338093941431555]
# average_precision_score_macro                      [0.7493125554205111]
# precision_score_macro                              [0.6667443917641006]
# precision_score_micro                              [0.8078907435508346]
# AUC_weighted                                       [0.8990871487662244]
# average_precision_score_weighted                   [0.9332314204786958]
# AUC_micro                                           [0.883341431008955]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_5  \
# balanced_accuracy                                  [0.5932768914155307]
# f1_score_macro                                     [0.6267831475663812]
# norm_macro_recall                                  [0.1865537828310615]
# average_precision_score_micro                      [0.9671544834138566]
# accuracy                                           [0.9001517450682853]
# f1_score_weighted                                  [0.8746567304785686]
# recall_score_micro                                 [0.9001517450682853]
# precision_score_weighted                           [0.8827113977984437]
# weighted_accuracy                                  [0.9763404704059276]
# f1_score_micro                                     [0.9001517450682853]
# matthews_correlation                              [0.33340661446628406]
# recall_score_weighted                              [0.9001517450682853]
# log_loss                                          [0.24666201741184207]
# AUC_macro                                          [0.8932544776575586]
# recall_score_macro                                 [0.5932768914155307]
# average_precision_score_macro                      [0.7308096880922401]
# precision_score_macro                              [0.7979300898726163]
# precision_score_micro                              [0.9001517450682853]
# AUC_weighted                                       [0.8932544776575585]
# average_precision_score_weighted                   [0.9280138663949072]
# AUC_micro                                          [0.9665864267605536]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_2  \
# balanced_accuracy                                                 [0.5]
# f1_score_macro                                     [0.4703423886834914]
# norm_macro_recall                                                 [0.0]
# average_precision_score_micro                       [0.967837487114666]
# accuracy                                           [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_weighted                            [0.788565560086672]
# weighted_accuracy                                  [0.9843450583187134]
# f1_score_micro                                     [0.8880121396054628]
# matthews_correlation                                              [0.0]
# recall_score_weighted                              [0.8880121396054628]
# log_loss                                           [0.2444853095139035]
# AUC_macro                                          [0.9001309630321184]
# recall_score_macro                                                [0.5]
# average_precision_score_macro                      [0.7374197566213732]
# precision_score_macro                              [0.4440060698027314]
# precision_score_micro                              [0.8880121396054628]
# AUC_weighted                                       [0.9001309630321185]
# average_precision_score_weighted                   [0.9295745513013062]
# AUC_micro                                          [0.9675954508716705]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_10  \
# balanced_accuracy                                    [0.824952254990766]
# f1_score_macro                                       [0.636289378987571]
# norm_macro_recall                                   [0.6499045099815319]
# average_precision_score_micro                        [0.867114237975045]
# accuracy                                            [0.7374810318664643]
# f1_score_weighted                                   [0.7851657060366679]
# recall_score_micro                                  [0.7374810318664643]
# precision_score_weighted                            [0.9109345971575565]
# weighted_accuracy                                   [0.7157642932212509]
# f1_score_micro                                      [0.7374810318664643]
# matthews_correlation                                [0.4268343933122343]
# recall_score_weighted                               [0.7374810318664643]
# log_loss                                           [0.49598798680578016]
# AUC_macro                                           [0.8944821403101249]
# recall_score_macro                                   [0.824952254990766]
# average_precision_score_macro                       [0.7476486077877043]
# precision_score_macro                               [0.6401648984705464]
# precision_score_micro                               [0.7374810318664643]
# AUC_weighted                                         [0.894482140310125]
# average_precision_score_weighted                    [0.9322500202101657]
# AUC_micro                                           [0.8557213417119331]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_0  \
# balanced_accuracy                                  [0.7513392683482543]
# f1_score_macro                                     [0.7653697272147331]
# norm_macro_recall                                  [0.5026785366965085]
# average_precision_score_micro                      [0.9806603102489483]
# accuracy                                           [0.9116843702579667]
# f1_score_weighted                                  [0.9091539479147899]
# recall_score_micro                                 [0.9116843702579667]
# precision_score_weighted                           [0.9072720074188747]
# weighted_accuracy                                  [0.9514937218005303]
# f1_score_micro                                     [0.9116843702579667]
# matthews_correlation                               [0.5323740218566827]
# recall_score_weighted                              [0.9116843702579667]
# log_loss                                          [0.17775706110025447]
# AUC_macro                                          [0.9450464668693166]
# recall_score_macro                                 [0.7513392683482543]
# average_precision_score_macro                      [0.8151093723721079]
# precision_score_macro                              [0.7819118765348991]
# precision_score_micro                              [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# average_precision_score_weighted                   [0.9531771295804466]
# AUC_micro                                           [0.979695082216353]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_4  \
# balanced_accuracy                                                 [0.5]
# f1_score_macro                                     [0.4703423886834914]
# norm_macro_recall                                                 [0.0]
# average_precision_score_micro                      [0.9645907291058802]
# accuracy                                           [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_weighted                            [0.788565560086672]
# weighted_accuracy                                  [0.9843450583187134]
# f1_score_micro                                     [0.8880121396054628]
# matthews_correlation                                              [0.0]
# recall_score_weighted                              [0.8880121396054628]
# log_loss                                          [0.27090963322851336]
# AUC_macro                                          [0.8834739287242497]
# recall_score_macro                                                [0.5]
# average_precision_score_macro                      [0.7056599174267693]
# precision_score_macro                              [0.4440060698027314]
# precision_score_micro                              [0.8880121396054628]
# AUC_weighted                                       [0.8834739287242497]
# average_precision_score_weighted                   [0.9205594622241539]
# AUC_micro                                          [0.9642824806979813]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_1  \
# balanced_accuracy                                  [0.7191727470931578]
# f1_score_macro                                     [0.7416848907681176]
# norm_macro_recall                                 [0.43834549418631563]
# average_precision_score_micro                      [0.9791945367231853]
# accuracy                                           [0.9071320182094081]
# f1_score_weighted                                  [0.9021127651963996]
# recall_score_micro                                 [0.9071320182094081]
# precision_score_weighted                           [0.8991976076061607]
# weighted_accuracy                                  [0.9537972210153172]
# f1_score_micro                                     [0.9071320182094081]
# matthews_correlation                                [0.488678780261868]
# recall_score_weighted                              [0.9071320182094081]
# log_loss                                           [0.1874363495858499]
# AUC_macro                                          [0.9392346349984347]
# recall_score_macro                                 [0.7191727470931578]
# average_precision_score_macro                      [0.8065229883244922]
# precision_score_macro                              [0.7723958081530135]
# precision_score_micro                              [0.9071320182094081]
# AUC_weighted                                       [0.9392346349984347]
# average_precision_score_weighted                   [0.9505970434373063]
# AUC_micro                                          [0.9781770788959222]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_6  \
# balanced_accuracy                                  [0.5909086278149179]
# f1_score_macro                                     [0.6238596220952524]
# norm_macro_recall                                 [0.18181725562983586]
# average_precision_score_micro                      [0.9649727078310646]
# accuracy                                           [0.9001517450682853]
# f1_score_weighted                                   [0.874029224943002]
# recall_score_micro                                 [0.9001517450682853]
# precision_score_weighted                           [0.8830870489340036]
# weighted_accuracy                                  [0.9769284461975132]
# f1_score_micro                                     [0.9001517450682853]
# matthews_correlation                                [0.331044134221627]
# recall_score_weighted                              [0.9001517450682853]
# log_loss                                          [0.25822722862568287]
# AUC_macro                                          [0.8786799778455747]
# recall_score_macro                                 [0.5909086278149179]
# average_precision_score_macro                      [0.7289620768913722]
# precision_score_macro                              [0.8013746369202237]
# precision_score_micro                              [0.9001517450682853]
# AUC_weighted                                       [0.8786799778455747]
# average_precision_score_weighted                   [0.9260353739870858]
# AUC_micro                                          [0.9637283694197996]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_8  \
# balanced_accuracy                                                 [0.5]
# f1_score_macro                                     [0.4703423886834914]
# norm_macro_recall                                                 [0.0]
# average_precision_score_micro                      [0.9658271907412427]
# accuracy                                           [0.8880121396054628]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_micro                                 [0.8880121396054628]
# precision_score_weighted                            [0.788565560086672]
# weighted_accuracy                                  [0.9843450583187134]
# f1_score_micro                                     [0.8880121396054628]
# matthews_correlation                                              [0.0]
# recall_score_weighted                              [0.8880121396054628]
# log_loss                                           [0.2732160129101926]
# AUC_macro                                           [0.888667066780032]
# recall_score_macro                                                [0.5]
# average_precision_score_macro                      [0.7333922777045214]
# precision_score_macro                              [0.4440060698027314]
# precision_score_micro                              [0.8880121396054628]
# AUC_weighted                                       [0.8886670667800322]
# average_precision_score_weighted                   [0.9274641523479698]
# AUC_micro                                          [0.9653153603312141]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_7  ...  \
# balanced_accuracy                                  [0.5013550135501355]  ...
# f1_score_macro                                    [0.47312070913357085]  ...
# norm_macro_recall                               [0.0027100271002709064]  ...
# average_precision_score_micro                      [0.9584481652374972]  ...
# accuracy                                           [0.8883156297420334]  ...
# f1_score_weighted                                  [0.8360791405851395]  ...
# recall_score_micro                                 [0.8883156297420334]  ...
# precision_score_weighted                           [0.9007928150046113]  ...
# weighted_accuracy                                  [0.9843874836349229]  ...
# f1_score_micro                                     [0.8883156297420334]  ...
# matthews_correlation                             [0.049063912865329386]  ...
# recall_score_weighted                              [0.8883156297420334]  ...
# log_loss                                          [0.27794739452526696]  ...
# AUC_macro                                          [0.8506081352679555]  ...
# recall_score_macro                                 [0.5013550135501355]  ...
# average_precision_score_macro                      [0.7222713792845927]  ...
# precision_score_macro                              [0.9441408621736491]  ...
# precision_score_micro                              [0.8883156297420334]  ...
# AUC_weighted                                       [0.8506081352679556]  ...
# average_precision_score_weighted                    [0.920426484817205]  ...
# AUC_micro                                          [0.9577461597444973]  ...
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_21  \
# balanced_accuracy                                    [0.628153439770898]
# f1_score_macro                                      [0.6696461623889437]
# norm_macro_recall                                    [0.256306879541796]
# average_precision_score_micro                       [0.9774270588941639]
# accuracy                                            [0.9053110773899848]
# f1_score_weighted                                   [0.8861733588164185]
# recall_score_micro                                  [0.9053110773899848]
# precision_score_weighted                            [0.8905400287071871]
# weighted_accuracy                                   [0.9741218218235597]
# f1_score_micro                                      [0.9053110773899848]
# matthews_correlation                                [0.3966883845702862]
# recall_score_weighted                               [0.9053110773899848]
# log_loss                                           [0.20981680406070358]
# AUC_macro                                           [0.9342526678855305]
# recall_score_macro                                   [0.628153439770898]
# average_precision_score_macro                       [0.7998616245795696]
# precision_score_macro                               [0.8069790298533953]
# precision_score_micro                               [0.9053110773899848]
# AUC_weighted                                        [0.9342526678855304]
# average_precision_score_weighted                    [0.9484874787008328]
# AUC_micro                                           [0.9763752961792019]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_19  \
# balanced_accuracy                                   [0.7603117179497154]
# f1_score_macro                                      [0.7714990790277103]
# norm_macro_recall                                   [0.5206234358994308]
# average_precision_score_micro                         [0.97995948805535]
# accuracy                                            [0.9128983308042489]
# f1_score_weighted                                   [0.9109890044878217]
# recall_score_micro                                  [0.9128983308042489]
# precision_score_weighted                            [0.9094687345892809]
# weighted_accuracy                                   [0.9507814593779897]
# f1_score_micro                                      [0.9128983308042489]
# matthews_correlation                                [0.5439783568775576]
# recall_score_weighted                               [0.9128983308042489]
# log_loss                                           [0.19004342216112807]
# AUC_macro                                           [0.9435423369954821]
# recall_score_macro                                  [0.7603117179497154]
# average_precision_score_macro                       [0.8148343616874545]
# precision_score_macro                               [0.7841904842796676]
# precision_score_micro                               [0.9128983308042489]
# AUC_weighted                                        [0.9435423369954822]
# average_precision_score_weighted                    [0.9528936181174027]
# AUC_micro                                           [0.9790037326063079]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_22  \
# balanced_accuracy                                   [0.7159621151918969]
# f1_score_macro                                      [0.7405646205646206]
# norm_macro_recall                                   [0.4319242303837938]
# average_precision_score_micro                       [0.9787471260989811]
# accuracy                                            [0.9077389984825494]
# f1_score_weighted                                   [0.9021770532058848]
# recall_score_micro                                  [0.9077389984825494]
# precision_score_weighted                            [0.8992110967163239]
# weighted_accuracy                                   [0.9553520111267004]
# f1_score_micro                                      [0.9077389984825494]
# matthews_correlation                               [0.48767795941601105]
# recall_score_weighted                               [0.9077389984825494]
# log_loss                                           [0.18853344489960672]
# AUC_macro                                           [0.9382454658449524]
# recall_score_macro                                  [0.7159621151918969]
# average_precision_score_macro                        [0.800921254969678]
# precision_score_macro                               [0.7753142511695126]
# precision_score_micro                               [0.9077389984825494]
# AUC_weighted                                        [0.9382454658449523]
# average_precision_score_weighted                    [0.9492807430329407]
# AUC_micro                                           [0.9776692049617645]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_28  \
# balanced_accuracy                                                  [0.5]
# f1_score_macro                                      [0.4703423886834914]
# norm_macro_recall                                                  [0.0]
# average_precision_score_micro                         [0.97474986519737]
# accuracy                                            [0.8880121396054628]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_micro                                  [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_micro                                      [0.8880121396054628]
# matthews_correlation                                               [0.0]
# recall_score_weighted                               [0.8880121396054628]
# log_loss                                            [0.2684414628119108]
# AUC_macro                                           [0.9306266405111078]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                       [0.7904832503311506]
# precision_score_macro                               [0.4440060698027314]
# precision_score_micro                               [0.8880121396054628]
# AUC_weighted                                        [0.9306266405111078]
# average_precision_score_weighted                    [0.9459201488993374]
# AUC_micro                                           [0.9736608325024582]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_31  \
# balanced_accuracy                                   [0.7124097197909778]
# f1_score_macro                                      [0.7384117513104482]
# norm_macro_recall                                  [0.42481943958195556]
# average_precision_score_micro                       [0.9780307267825393]
# accuracy                                            [0.9077389984825494]
# f1_score_weighted                                    [0.901734939171279]
# recall_score_micro                                  [0.9077389984825494]
# precision_score_weighted                            [0.8987262915460366]
# weighted_accuracy                                   [0.9562339748140789]
# f1_score_micro                                      [0.9077389984825494]
# matthews_correlation                                [0.4843785549832882]
# recall_score_weighted                               [0.9077389984825494]
# log_loss                                            [0.1957832423354532]
# AUC_macro                                           [0.9348190320590833]
# recall_score_macro                                  [0.7124097197909778]
# average_precision_score_macro                       [0.8013816819389603]
# precision_score_macro                               [0.7761438892233594]
# precision_score_micro                               [0.9077389984825494]
# AUC_weighted                                        [0.9348190320590832]
# average_precision_score_weighted                    [0.9489850016507141]
# AUC_micro                                           [0.9769387101899463]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_34  \
# balanced_accuracy                                   [0.7572840082467811]
# f1_score_macro                                      [0.7743555195708202]
# norm_macro_recall                                   [0.5145680164935622]
# average_precision_score_micro                       [0.9805253710646454]
# accuracy                                            [0.9159332321699545]
# f1_score_weighted                                   [0.9130582824505085]
# recall_score_micro                                  [0.9159332321699545]
# precision_score_weighted                            [0.9111231376981217]
# weighted_accuracy                                   [0.9553215430811842]
# f1_score_micro                                      [0.9159332321699545]
# matthews_correlation                                [0.5510796066559864]
# recall_score_weighted                               [0.9159332321699545]
# log_loss                                           [0.18011527626106247]
# AUC_macro                                           [0.9453243233731039]
# recall_score_macro                                  [0.7572840082467811]
# average_precision_score_macro                       [0.8113583956800483]
# precision_score_macro                               [0.7950909531275894]
# precision_score_micro                               [0.9159332321699545]
# AUC_weighted                                        [0.9453243233731039]
# average_precision_score_weighted                    [0.9523358020200623]
# AUC_micro                                           [0.9795858441884402]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_56  \
# balanced_accuracy                                   [0.7347271541751644]
# f1_score_macro                                       [0.601861496436287]
# norm_macro_recall                                  [0.46945430835032886]
# average_precision_score_micro                       [0.8022212679761336]
# accuracy                                            [0.7265553869499242]
# f1_score_weighted                                   [0.7747694563296548]
# recall_score_micro                                  [0.7265553869499242]
# precision_score_weighted                            [0.8787554090628754]
# weighted_accuracy                                   [0.7245265581904603]
# f1_score_micro                                      [0.7265553869499242]
# matthews_correlation                               [0.31523856052317184]
# recall_score_weighted                               [0.7265553869499242]
# log_loss                                            [0.5833563736720102]
# AUC_macro                                           [0.8157519630561993]
# recall_score_macro                                  [0.7347271541751644]
# average_precision_score_macro                       [0.7069793279645711]
# precision_score_macro                               [0.6058413441660897]
# precision_score_micro                               [0.7265553869499242]
# AUC_weighted                                        [0.8157519630561992]
# average_precision_score_weighted                    [0.9092451355142399]
# AUC_micro                                           [0.8245852800375794]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_66  \
# balanced_accuracy                                   [0.6646906438305668]
# f1_score_macro                                      [0.7018077993422241]
# norm_macro_recall                                   [0.3293812876611335]
# average_precision_score_micro                       [0.9768158730698882]
# accuracy                                            [0.9050075872534142]
# f1_score_weighted                                   [0.8928305411396187]
# recall_score_micro                                  [0.9050075872534142]
# precision_score_weighted                            [0.8908085270667904]
# weighted_accuracy                                   [0.9646717838419793]
# f1_score_micro                                      [0.9050075872534142]
# matthews_correlation                               [0.42904881088518765]
# recall_score_weighted                               [0.9050075872534142]
# log_loss                                            [0.2027688209104494]
# AUC_macro                                           [0.9311828166128551]
# recall_score_macro                                  [0.6646906438305668]
# average_precision_score_macro                       [0.7845569826018335]
# precision_score_macro                               [0.7794373709404181]
# precision_score_micro                               [0.9050075872534142]
# AUC_weighted                                        [0.9311828166128551]
# average_precision_score_weighted                    [0.9448337846214855]
# AUC_micro                                           [0.9756535515023682]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_68  \
# balanced_accuracy                                   [0.6344158622720881]
# f1_score_macro                                      [0.6763876568242302]
# norm_macro_recall                                  [0.26883172454417625]
# average_precision_score_micro                       [0.9764787599839468]
# accuracy                                            [0.9059180576631259]
# f1_score_weighted                                   [0.8878864802278541]
# recall_score_micro                                  [0.9059180576631259]
# precision_score_weighted                            [0.8913185880075751]
# weighted_accuracy                                   [0.9733247087686001]
# f1_score_micro                                      [0.9059180576631259]
# matthews_correlation                                [0.4054162196296957]
# recall_score_weighted                               [0.9059180576631259]
# log_loss                                           [0.21120718675942152]
# AUC_macro                                           [0.9306118214975725]
# recall_score_macro                                  [0.6344158622720881]
# average_precision_score_macro                       [0.7862602542498243]
# precision_score_macro                               [0.8056973863808705]
# precision_score_micro                               [0.9059180576631259]
# AUC_weighted                                        [0.9306118214975726]
# average_precision_score_weighted                    [0.9450789960098217]
# AUC_micro                                           [0.9754227332073013]
#
#                                  8438967f-0359-4a20-8688-88c4be141fbc_72
# balanced_accuracy                                   [0.6879087963811968]
# f1_score_macro                                      [0.7286092769777753]
# norm_macro_recall                                   [0.3758175927623937]
# average_precision_score_micro                       [0.9808751061493207]
# accuracy                                            [0.9125948406676783]
# f1_score_weighted                                   [0.9020155012148126]
# recall_score_micro                                  [0.9125948406676783]
# precision_score_weighted                            [0.9013350018249878]
# weighted_accuracy                                   [0.9683783078093512]
# f1_score_micro                                      [0.9125948406676783]
# matthews_correlation                               [0.48197147030587134]
# recall_score_weighted                               [0.9125948406676783]
# log_loss                                           [0.19894043647580636]
# AUC_macro                                           [0.9472304189890839]
# recall_score_macro                                  [0.6879087963811968]
# average_precision_score_macro                       [0.8236619287410819]
# precision_score_macro                               [0.8090548482328102]
# precision_score_micro                               [0.9125948406676783]
# AUC_weighted                                         [0.947230418989084]
# average_precision_score_weighted                    [0.9552932461536223]
# AUC_micro                                           [0.9799318874185149]
#
# [21 rows x 67 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/8438967f-0359-4a20-8688-88c4be141fbc/model_data
# Downloaded azureml/8438967f-0359-4a20-8688-88c4be141fbc/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                 seed=None,
#                                                                                                                                 silent=None,
#                                                                                                                                 subsample=0.7,
#                                                                                                                                 tree_method='auto',
#                                                                                                                                 verbose=-10,
#                                                                                                                                 verbosity=0))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.2,
#                                                                                          0.06666666666666667,
#                                                                                          0.2,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('52',
#                                              Pipeline(memory=None,
#                                                       steps=[('standardscalerwrapper',
#                                                               <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7f0912ecd550>),
#                                                              ('xgboostclassifier',
#                                                               XGBoostClassifier(base_score=0.5,
#                                                                                 booster='gbtree',
#                                                                                 colsample_bylevel=1,
#                                                                                 colsample_bynode=1,
#                                                                                 colsample_bytree=1,
#                                                                                 e...
#                                                                                 random_state=0,
#                                                                                 reg_alpha=1.875,
#                                                                                 reg_lambda=0.8333333333333334,
#                                                                                 scale_pos_weight=1,
#                                                                                 seed=None,
#                                                                                 silent=None,
#                                                                                 subsample=0.7,
#                                                                                 tree_method='auto',
#                                                                                 verbose=-10,
#                                                                                 verbosity=0))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.06666666666666667, 0.13333333333333333,
#                                          0.13333333333333333, 0.06666666666666667,
#                                          0.06666666666666667, 0.2,
#                                          0.06666666666666667, 0.2,
#                                          0.06666666666666667]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row0_col0" class="data row0 col0" >29089</td>
#                         <td id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row0_col1" class="data row0 col1" >169</td>
#             </tr>
#             <tr>
#                         <th id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row1_col0" class="data row1 col0" >1552</td>
#                         <td id="T_3023d2fa_bc85_11eb_92fa_3d5bec32f8a2row1_col1" class="data row1 col1" >2140</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: ab59572a-9b07-437d-ba70-57da0a5c5c32,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourceGroups/aml-quickstarts-145533/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-145533/PipelineRuns/PipelineSubmit/ab59572a-9b07-437d-ba70-57da0a5c5c32)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  433f7ac0-a822-491d-9d05-99d514e92679

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
